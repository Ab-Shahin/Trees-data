# %% [markdown]
# import pandas as pd
# pd.set_option('display.max_columns', None )

# %% [markdown]
# tree_census = pd.read_csv("c:/2015_Street_Tree_Data.csv")
# tree_census

# %% [raw]
# tree_census.columns

# %%
# A subset of the tree dataset containing columns that I will further clean and analyse 

tree_census_st = tree_census[['tree_id', 'tree_dbh', 'stump_diam',
       'curb_loc', 'status', 'health', 'spc_latin', 'spc_common', 'steward',
       'sidewalk', 'user_type', 'problems', 'root_stone',
       'root_grate', 'root_other', 'trunk_wire', 'trnk_light', 'trnk_other'
       ]]

# %%
tree_census_st
# Out:
#         tree_id  tree_dbh  stump_diam curb_loc status health  \
# 0        180683         3           0   OnCurb  Alive   Fair
# 1        200540        21           0   OnCurb  Alive   Fair
# 2        204026         3           0   OnCurb  Alive   Good
# 3        204337        10           0   OnCurb  Alive   Good
# 4        189565        21           0   OnCurb  Alive   Good
# ...         ...       ...         ...      ...    ...    ...
# 683783   155433        25           0   OnCurb  Alive   Good
# 683784   183795         7           0   OnCurb  Alive   Good
# 683785   166161        12           0   OnCurb  Alive   Good
# 683786   184028         9           0   OnCurb  Alive   Good
# 683787   200607        23           0   OnCurb  Alive   Fair
#
#                                  spc_latin           spc_common steward  \
# 0                              Acer rubrum            red maple    None
# 1                        Quercus palustris              pin oak    None
# ...

# %%
# count of na values
tree_census_st.isna().sum()
# Out:
# tree_id           0
# tree_dbh          0
# stump_diam        0
# curb_loc          0
# status            0
# health        31616
# spc_latin     31619
# spc_common    31619
# steward       31615
# sidewalk      31616
# user_type         0
# problems      31664
# root_stone        0
# root_grate        0
# root_other        0
# trunk_wire        0
# trnk_light        0
# trnk_other        0
# dtype: int64

# %%
# Health column na values. I find this subset only contains dead trees or stumps, hence the na-health values
tree_census_st[tree_census_st['health'].isna()]
# Out:
#         tree_id  tree_dbh  stump_diam        curb_loc status health spc_latin  \
# 37       211205         0          16          OnCurb  Stump    NaN       NaN
# 57       187807         0           0          OnCurb   Dead    NaN       NaN
# 196      208322        10           0          OnCurb   Dead    NaN       NaN
# 209      209058         6           0          OnCurb   Dead    NaN       NaN
# 239      203597         0          15          OnCurb  Stump    NaN       NaN
# ...         ...       ...         ...             ...    ...    ...       ...
# 683693   156162         3           0  OffsetFromCurb   Dead    NaN       NaN
# 683695   170888         0           5          OnCurb  Stump    NaN       NaN
# 683697   177922         0          17          OnCurb  Stump    NaN       NaN
# 683698   193791         3           0          OnCurb   Dead    NaN       NaN
# 683699   172660         0           4          OnCurb  Stump    NaN       NaN
#
# ...

# %%
tree_census_st.dtypes
# Out:
# tree_id        int64
# tree_dbh       int64
# stump_diam     int64
# curb_loc      object
# status        object
# health        object
# spc_latin     object
# spc_common    object
# steward       object
# sidewalk      object
# user_type     object
# problems      object
# root_stone    object
# root_grate    object
# root_other    object
# trunk_wire    object
# trnk_light    object
# trnk_other    object
# dtype: object

# %%
tree_census_st.describe()
# Out:
#              tree_id       tree_dbh     stump_diam
# count  683788.000000  683788.000000  683788.000000
# mean   365205.011085      11.279787       0.432463
# std    208122.092902       8.723042       3.290241
# min         3.000000       0.000000       0.000000
# 25%    186582.750000       4.000000       0.000000
# 50%    366214.500000       9.000000       0.000000
# 75%    546170.250000      16.000000       0.000000
# max    722694.000000     450.000000     140.000000

# %%
tree_census_st.hist(bins=60, figsize=(20,10))
# Out:
# array([[<AxesSubplot:title={'center':'tree_id'}>,
#         <AxesSubplot:title={'center':'tree_dbh'}>],
#        [<AxesSubplot:title={'center':'stump_diam'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
# trees with breast diameter more than 50 inches
big_trees =  tree_census_st[tree_census_st['tree_dbh']>50]
big_trees
# Out:
#         tree_id  tree_dbh  stump_diam        curb_loc status health  \
# 2405     168583       425           0          OnCurb  Alive   Good
# 3738     199546        51           0          OnCurb  Alive   Good
# 4887     139665        72           0  OffsetFromCurb  Alive   Good
# 6724     209349       122           0          OnCurb  Alive   Good
# 10083    215075       169           0          OnCurb  Alive   Good
# ...         ...       ...         ...             ...    ...    ...
# 675265   179496        52           0  OffsetFromCurb  Alive   Good
# 677954   166796        54           0          OnCurb  Alive   Good
# 679894   169501        51           0          OnCurb  Alive   Good
# 681736   179366       281           0          OnCurb  Alive   Fair
# 682788   183910       127           0          OnCurb   Dead    NaN
#
#                                  spc_latin       spc_common steward  sidewalk  \
# ...

# %%
# stump diameter more than 50 inches
big_stump =  tree_census_st[tree_census_st['stump_diam']>50]
big_stump
# Out:
#         tree_id  tree_dbh  stump_diam curb_loc status health spc_latin  \
# 6122     200925         0          52   OnCurb  Stump    NaN       NaN
# 6177     200924         0          55   OnCurb  Stump    NaN       NaN
# 6466     166008         0          72   OnCurb  Stump    NaN       NaN
# 7042     206818         0         100   OnCurb  Stump    NaN       NaN
# 9872     192215         0          53   OnCurb  Stump    NaN       NaN
# ...         ...       ...         ...      ...    ...    ...       ...
# 645994   135904         0          65   OnCurb  Stump    NaN       NaN
# 646336   151125         0          55   OnCurb  Stump    NaN       NaN
# 649174   154188         0          65   OnCurb  Stump    NaN       NaN
# 652690   154181         0          60   OnCurb  Stump    NaN       NaN
# 653066   154190         0          80   OnCurb  Stump    NaN       NaN
#
#        spc_common steward sidewalk         user_type problems root_stone  \
# ...

# %%
big_stump[['tree_id', 'stump_diam']].plot(kind='scatter', x='tree_id', y='stump_diam', figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='tree_id', ylabel='stump_diam'>

# %%
big_trees[['tree_id', 'tree_dbh']].plot(kind='scatter', x='tree_id', y='tree_dbh', figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='tree_id', ylabel='tree_dbh'>

# %%
tree_census_st['steward'].value_counts()
# Out:
# None       487823
# 1or2       143557
# 3or4        19183
# 4orMore      1610
# Name: steward, dtype: int64

# %%
tree_census_st['sidewalk'].value_counts()
# Out:
# NoDamage    464978
# Damage      187194
# Name: sidewalk, dtype: int64

# %%
# stumps and dead tress
stumps = tree_census_st[tree_census_st['status']=='Stump']
stumps
# Out:
#         tree_id  tree_dbh  stump_diam curb_loc status health spc_latin  \
# 37       211205         0          16   OnCurb  Stump    NaN       NaN
# 239      203597         0          15   OnCurb  Stump    NaN       NaN
# 641      179766         0          30   OnCurb  Stump    NaN       NaN
# 644      180619         0          10   OnCurb  Stump    NaN       NaN
# 646      208828         0          15   OnCurb  Stump    NaN       NaN
# ...         ...       ...         ...      ...    ...    ...       ...
# 683348   152836         0          13   OnCurb  Stump    NaN       NaN
# 683686   191219         0          25   OnCurb  Stump    NaN       NaN
# 683695   170888         0           5   OnCurb  Stump    NaN       NaN
# 683697   177922         0          17   OnCurb  Stump    NaN       NaN
# 683699   172660         0           4   OnCurb  Stump    NaN       NaN
#
#        spc_common steward sidewalk         user_type problems root_stone  \
# ...

# %%
dead_trees = tree_census_st[tree_census_st['status']=='Dead']
dead_trees
# Out:
#         tree_id  tree_dbh  stump_diam        curb_loc status health spc_latin  \
# 57       187807         0           0          OnCurb   Dead    NaN       NaN
# 196      208322        10           0          OnCurb   Dead    NaN       NaN
# 209      209058         6           0          OnCurb   Dead    NaN       NaN
# 266      210544         6           0          OnCurb   Dead    NaN       NaN
# 285      188609         9           0          OnCurb   Dead    NaN       NaN
# ...         ...       ...         ...             ...    ...    ...       ...
# 682816   184342        11           0          OnCurb   Dead    NaN       NaN
# 682823   155430         2           0          OnCurb   Dead    NaN       NaN
# 683346   156566        10           0          OnCurb   Dead    NaN       NaN
# 683693   156162         3           0  OffsetFromCurb   Dead    NaN       NaN
# 683698   193791         3           0          OnCurb   Dead    NaN       NaN
#
# ...

# %%
# looking at root and trunk data
tree_ss = tree_census_st[['root_stone', 'root_grate', 'root_other', 'trunk_wire','trnk_light', 'trnk_other']]
tree_ss
# Out:
#        root_stone root_grate root_other trunk_wire trnk_light trnk_other
# 0              No         No         No         No         No         No
# 1             Yes         No         No         No         No         No
# 2              No         No         No         No         No         No
# 3             Yes         No         No         No         No         No
# 4             Yes         No         No         No         No         No
# ...           ...        ...        ...        ...        ...        ...
# 683783         No         No         No         No         No         No
# 683784         No         No         No         No         No         No
# 683785         No         No         No         No         No         No
# 683786         No         No         No         No         No         No
# 683787         No         No         No         No         No         No
#
# [683543 rows x 6 columns]

# %%
tree_ss .apply(pd.Series.value_counts)
# Out:
#      root_stone  root_grate  root_other  trunk_wire  trnk_light  trnk_other
# No       543584      680007      653229      670276      682512      650984
# Yes      139959        3536       30314       13267        1031       32559

# %%
# trees species
tree_census_st['spc_latin'].value_counts()
# Out:
# Platanus x acerifolia                 86987
# Gleditsia triacanthos var. inermis    64254
# Pyrus calleryana                      58914
# Quercus palustris                     53169
# Acer platanoides                      34183
#                                       ...
# Pinus rigida                             33
# Maclura pomifera                         29
# Pinus sylvestris                         25
# Pinus virginiana                         10
# No Observation                            5
# Name: spc_latin, Length: 134, dtype: int64

# %%
pd.DataFrame(tree_census_st['spc_latin'].value_counts()).plot(kind='bar', figsize=(20,10))
# Out:
# <AxesSubplot:>

# %%
# cleaning some of the data variations and na values

# %%
# filling up all the na values of the stump and dead trees with 'Not Applicable'
mask = ((tree_census_st['status'] == 'Stump') | (tree_census_st['status'] == 'Dead'))
tree_census_st.loc[mask] = tree_census_st.loc[mask].fillna('Not Applicable')

# %%
# Excluding all the extreme diameters values to calculate a more accurate values' means and maxes 
tree_census_st = tree_census_st[(tree_census_st['tree_dbh']<=60) & (tree_census_st['stump_diam']<=60)]
tree_census_st
# Out:
#         tree_id  tree_dbh  stump_diam curb_loc status health  \
# 0        180683         3           0   OnCurb  Alive   Fair
# 1        200540        21           0   OnCurb  Alive   Fair
# 2        204026         3           0   OnCurb  Alive   Good
# 3        204337        10           0   OnCurb  Alive   Good
# 4        189565        21           0   OnCurb  Alive   Good
# ...         ...       ...         ...      ...    ...    ...
# 683783   155433        25           0   OnCurb  Alive   Good
# 683784   183795         7           0   OnCurb  Alive   Good
# 683785   166161        12           0   OnCurb  Alive   Good
# 683786   184028         9           0   OnCurb  Alive   Good
# 683787   200607        23           0   OnCurb  Alive   Fair
#
#                                  spc_latin           spc_common steward  \
# 0                              Acer rubrum            red maple    None
# 1                        Quercus palustris              pin oak    None
# ...

# %%
# filling up na values with most common or logical values
tree_census_st['problems'].fillna('None', inplace=True)
tree_census_st['health'].fillna('Good', inplace=True)
tree_census_st['spc_latin'].fillna('No Observation', inplace=True)
tree_census_st['sidewalk'].fillna('NoDamage', inplace=True)
tree_census_st['spc_common'].fillna('No Observation', inplace=True)
tree_census_st.isna().sum()
# Out:
# tree_id       0
# tree_dbh      0
# stump_diam    0
# curb_loc      0
# status        0
# health        0
# spc_latin     0
# spc_common    0
# steward       0
# sidewalk      0
# user_type     0
# problems      0
# root_stone    0
# root_grate    0
# root_other    0
# trunk_wire    0
# trnk_light    0
# trnk_other    0
# dtype: int64

# %%
# creating alive and dead data subsets
trees_stump_alive = tree_census_st[tree_census_st['status'] == 'Alive']
trees_stump_or_dead = tree_census_st[(tree_census_st['status'] == 'Stump') | (tree_census_st['status'] == 'Dead')]

# %%
alive_stats = trees_stump_alive.groupby('spc_latin')['tree_dbh'].describe()
alive_stats
# Out:
#                      count       mean       std  min  25%   50%   75%   max
# spc_latin
# Acer                7080.0  10.901130  3.238654  7.0  7.0  11.0  15.0  15.0
# Acer buergerianum    110.0   7.527273  2.057473  5.0  5.0   8.0  10.0  10.0
# Acer campestre      2549.0   6.409180  2.073060  4.0  4.0   6.0   9.0   9.0
# Acer ginnala        2049.0   7.076623  2.440200  4.0  4.0   7.0  10.0  10.0
# Acer griseum         220.0   2.454545  0.499065  2.0  2.0   2.0   3.0   3.0
# ...                    ...        ...       ...  ...  ...   ...   ...   ...
# Tsuga canadensis      88.0   4.227273  2.032649  2.0  2.0   3.5   7.0   7.0
# Ulmus americana     7972.0  10.110637  5.370087  4.0  4.0   9.0  17.0  17.0
# Ulmus parvifolia    5344.0   6.147455  2.781917  3.0  3.0   5.0  10.0  10.0
# Ulmus pumila        1593.0   9.957313  5.332011  4.0  4.0   9.0  17.0  17.0
# Zelkova serrata    29253.0   7.039175  2.856205  4.0  4.0   6.0  11.0  11.0
#
# [133 rows x 8 columns]

# %%
# merging the alive dataset with stats subset to correct values deviations for tree_dbh
trees_stump_alive = trees_stump_alive.merge(alive_stats, on='spc_latin', how='left')
trees_stump_alive
# Out:
#         tree_id  tree_dbh  stump_diam curb_loc status health  \
# 0        180683         3           0   OnCurb  Alive   Fair
# 1        200540        21           0   OnCurb  Alive   Fair
# 2        204026         3           0   OnCurb  Alive   Good
# 3        204337        10           0   OnCurb  Alive   Good
# 4        189565        21           0   OnCurb  Alive   Good
# ...         ...       ...         ...      ...    ...    ...
# 652018   155433        25           0   OnCurb  Alive   Good
# 652019   183795         7           0   OnCurb  Alive   Good
# 652020   166161        12           0   OnCurb  Alive   Good
# 652021   184028         9           0   OnCurb  Alive   Good
# 652022   200607        23           0   OnCurb  Alive   Fair
#
#                                  spc_latin           spc_common steward  \
# 0                              Acer rubrum            red maple    None
# 1                        Quercus palustris              pin oak    None
# ...

# %%
mask = trees_stump_alive['tree_dbh']< trees_stump_alive['25%']
trees_stump_alive.loc[mask,'tree_dbh' ] = trees_stump_alive['25%']

mask = trees_stump_alive['tree_dbh'] > trees_stump_alive['75%']
trees_stump_alive.loc[mask, 'tree_dbh'] = trees_stump_alive['75%']

# %%
# tree_dbh values have been adjusted to fit within 25 and 75 percentiles 
trees_stump_alive
# Out:
#         tree_id  tree_dbh  stump_diam curb_loc status health  \
# 0        180683       5.0           0   OnCurb  Alive   Fair
# 1        200540      21.0           0   OnCurb  Alive   Fair
# 2        204026       6.0           0   OnCurb  Alive   Good
# 3        204337      10.0           0   OnCurb  Alive   Good
# 4        189565      12.0           0   OnCurb  Alive   Good
# ...         ...       ...         ...      ...    ...    ...
# 652018   155433      24.0           0   OnCurb  Alive   Good
# 652019   183795       5.0           0   OnCurb  Alive   Good
# 652020   166161      12.0           0   OnCurb  Alive   Good
# 652021   184028       9.0           0   OnCurb  Alive   Good
# 652022   200607      14.0           0   OnCurb  Alive   Fair
#
#                                  spc_latin           spc_common steward  \
# 0                              Acer rubrum            red maple    None
# 1                        Quercus palustris              pin oak    None
# ...
